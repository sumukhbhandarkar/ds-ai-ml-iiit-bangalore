# %%
import matplotlib.pyplot as plt
import numpy as np

product_category = np.array(['Furniture', 'Technology', 'Office Supplies'])
sales = np.array([4110451.90, 4744557.50, 3787492.52])

# %%
plt.bar(product_category, sales)
plt.show()

# %%
# plot the same bar chart, setting bar width to 0.5 and align to center
plt.bar(product_category, sales, width=0.5, align='center', edgecolor='Orange', color='cyan')
# Adding title and format
plt.title("Sales across Different Products\n", fontdict={'fontsize': 20, 'fontweight': 5, 'color': 'Green'})
#Labelling axes
plt.xlabel("Product Category", fontdict={'fontsize': 12, 'fontweight': 5, 'color': 'Brown'})
plt.ylabel("Sales", fontdict={'fontsize': 12, 'fontweight': 5, 'color': 'Brown'})
#Show information in million dollars instead of 1 2 3 4 etc
ticks = np.arange(0, 6000000, 1000000)
labels = ["{}M".format(i//1000000) for i in ticks]
plt.yticks(ticks, labels)
# Out:
# ([<matplotlib.axis.YTick at 0x10b624f40>,
#   <matplotlib.axis.YTick at 0x10b624d00>,
#   <matplotlib.axis.YTick at 0x10b624250>,
#   <matplotlib.axis.YTick at 0x10b5f5f40>,
#   <matplotlib.axis.YTick at 0x10b5ff820>,
#   <matplotlib.axis.YTick at 0x10b605610>],
#  [Text(0, 0, '0M'),
#   Text(0, 1000000, '1M'),
#   Text(0, 2000000, '2M'),
#   Text(0, 3000000, '3M'),
#   Text(0, 4000000, '4M'),
#   Text(0, 5000000, '5M')])

# %%
ticks
# Out:
# array([      0, 1000000, 2000000, 3000000, 4000000, 5000000])
